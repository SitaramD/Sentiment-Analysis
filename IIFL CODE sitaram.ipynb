# %%
# https://api.iiflsecurities.com/vendor-login.html

# %%
# Partner Login
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQLoginForVendor",
    "userId": "KgKgC0DSj3H",
    "password": "lfjnfS7rHGjEFzZ3xJHKww=="
  },
  "body": {
    "Email_id": "sitaram.dod@gmail.com",
    "LocalIP": "123.123.123.123",
    "PublicIP": "123.123.123.12",
    "ContactNumber": "9652994444"
  }
}
# Out:
# {'head': {'appName': 'IIFLMarSITA RAM',
#   'appVer': '1.0',
#   'key': 'xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz',
#   'osName': 'Android',
#   'requestCode': 'IIFLMarRQLoginForVendor',
#   'userId': 'KgKgC0DSj3H',
#   'password': 'lfjnfS7rHGjEFzZ3xJHKww=='},
#  'body': {'Email_id': 'sitaram.dod@gmail.com',
#   'LocalIP': '123.123.123.123',
#   'PublicIP': '123.123.123.12',
#   'ContactNumber': '9652994444'}}

# %%
# Market Feed

{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQMarketFeed",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450",
    "Count": "2",
    "MarketFeedData": [
      {
        "Exch": "N",
        "ExchType": "C",
        "ScripCode": "2885"
      },
      {
        "Exch": "N",
        "ExchType": "C",
        "ScripCode": "22"
      }
    ],
    "ClientLoginType": "0",
    "LastRequestTime": "/Date(1576480500000)/",
    "RefreshRate": "H"
  }
}
# Out:
# {'head': {'appName': 'IIFLMarSITA RAM',
#   'appVer': '1.0',
#   'key': 'xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz',
#   'osName': 'Android',
#   'requestCode': 'IIFLMarRQMarketFeed',
#   'userId': 'KgKgC0DSj3H',
#   'password': 'eAEJaXRkgPn'},
#  'body': {'ClientCode': '18143450',
#   'Count': '2',
#   'MarketFeedData': [{'Exch': 'N', 'ExchType': 'C', 'ScripCode': '2885'},
#    {'Exch': 'N', 'ExchType': 'C', 'ScripCode': '22'}],
#   'ClientLoginType': '0',
#   'LastRequestTime': '/Date(1576480500000)/',
#   'RefreshRate': 'H'}}

# %%
# Historical Candle Data
{
  "ClientCode": "18143450",
  "JwtCode": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1bmlxdWVfbmFtZSI6IlNVUlZJTkhBIiwicm9sZSI6IjYwIiwibmJmIjoxNjIxOTU3NjU1LCJleHAiOjE2MjE5NjEyNTUsImlhdCI6MTYyMTk1NzY1NX0.DYO96m-OTF2-_WJ-Aw6VWlZQChaI8aIyn5wLaecfdoY"
}
# Out:
# {'ClientCode': '18143450',
#  'JwtCode': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1bmlxdWVfbmFtZSI6IlNVUlZJTkhBIiwicm9sZSI6IjYwIiwibmJmIjoxNjIxOTU3NjU1LCJleHAiOjE2MjE5NjEyNTUsImlhdCI6MTYyMTk1NzY1NX0.DYO96m-OTF2-_WJ-Aw6VWlZQChaI8aIyn5wLaecfdoY'}

# %%
# Order Request

{
  "_ReqData": {
    "head": {
      "requestCode": "IIFLMarRQOrdReq",
      "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
      "appVer": "5.6.0.0",
      "appName": "IIFLMarSITA RAM",
      "osName": "Android",
      "userId": "KgKgC0DSj3H",
      "password": "eAEJaXRkgPn"
    },
    "body": {
      "ClientCode": "18143450",
      "OrderFor": "P",
      "Exchange": "N",
      "ExchangeType": "C",
      "Price": 1164,
      "OrderID": 2,
      "OrderType": "BUY",
      "Qty": 1,
      "OrderDateTime": "/Date(1563857357612)/",
      "ScripCode": 2885,
      "AtMarket": false,
      "RemoteOrderID": "s0002201907231019172",
      "ExchOrderID": "0",
      "DisQty": 0,
      "IsStopLossOrder": false,
      "StopLossPrice": 1170,
      "IsVTD": false,
      "IOCOrder": false,
      "IsIntraday": false,
      "PublicIP": "192.168.84.215",
      "AHPlaced": "N",
      "ValidTillDate": "/Date(1563857357611)/",
      "iOrderValidity": 0,
      "OrderRequesterCode": "Dummy123",
      "TradedQty": 0
    }
  },
  "AppSource": 58
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-e2221357ff10> in <module>
#      23       "OrderDateTime": "/Date(1563857357612)/",
#      24       "ScripCode": 2885,
# ---> 25       "AtMarket": false,
#      26       "RemoteOrderID": "s0002201907231019172",
#      27       "ExchOrderID": "0",
#
# NameError: name 'false' is not defined

# %%
# Place Bracket/Cover Order
{
  "p_data": {
    "head": {
      "appName": "IIFLMarSITA RAM",
      "appVer": "1.0",
      "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
      "osName": "Android",
      "requestCode": "IIFLMarRQPSMOOrder",
      "userId": "KgKgC0DSj3H",
      "password": "eAEJaXRkgPn"
    },
    "body": {
      "ClientCode": "S0002",
      "OrderRequesterCode": "S0002",
      "RequestType": "P",
      "BuySell": "B",
      "Qty": 10,
      "Exch": "N",
      "ExchType": "C",
      "ExchOrderId": 0,
      "DisQty": 0,
      "AtMarket": false,
      "LimitPriceInitialOrder": 2201,
      "TriggerPriceInitialOrder": 0,
      "LimitPriceProfitOrder": 2190,
      "LimitPriceForSL": 0,
      "TriggerPriceForSL": 0,
      "TrailingSL": 0.005,
      "StopLoss": false,
      "ScripCode": 2885,
      "OrderFor": "S",
      "UniqueOrderIDNormal": "S00021201411250717042",
      "UniqueOrderIDSL": "S00021201411250717043",
      "UniqueOrderIDLimit": "S00021201411250717041",
      "LocalOrderIDNormal": 2,
      "LocalOrderIDSL": 3,
      "LocalOrderIDLimit": 1,
      "PublicIP": "192.168.151.73"
    }
  },
  "AppSource": 89
}

# %%
# Modify Bracket/Cover Order
{
  "p_data": {
    "head": {
      "appName": "IIFLMarSITA RAM",
      "appVer": "1.0",
      "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
      "osName": "Android",
      "requestCode": "IIFLMarRQAMSMOOrde",
      "userId": "KgKgC0DSj3H",
      "password": "eAEJaXRkgPn"
    },
    "body": {
      "ClientCode": "S0002",
      "OrderRequesterCode": "S0002",
      "OrderFor": "M",
      "Exchange": "N",
      "ExchangeType": "C",
      "ScripCode": 2885,
      "Price": 2210,
      "OrderID": 0,
      "OrderType": "buy",
      "Qty": 9,
      "OrderDateTime": "/Date(1557308002000)/",
      "AtMarket": false,
      "RemoteOrderID": "0",
      "ExchOrderID": "1100000000007917",
      "DisQty": 0,
      "IsStopLossOrder": false,
      "StopLossPrice": 0,
      "IOCOrder": false,
      "IsIntraday": false,
      "ValidTillDate": "/Date(1557308057777+0530)/",
      "AHPlaced": "N",
      "PublicIP": "192.168.84.215",
      "iOrderValidity": 0,
      "TrailingSL": 0.005,
      "LegType": 0,
      "TMOPartnerOrderID": 0
    }
  },
  "AppSource": 89
}

# %%
# Order Status
{
  "head": {
    "responseCode": "IIFLMarRQOrdStatus",
    "status": "0",
    "statusDescription": "Success"
  },
  "body": {
    "Message": "",
    "OrdStatusResLst": [
      {
        "Exch": "N",
        "ExchOrderID": 1100000000031379,
        "ExchOrderTime": "/Date(1557136685000+0530)/",
        "ExchType": "C",
        "OrderQty": 5,
        "OrderRate": 350,
        "PendingQty": 0,
        "ScripCode": 4717,
        "Status": "Placed",
        "Symbol": "GAIL",
        "TradedQty": 5
      }
    ],
    "Status": 0
  }
}

# %%
# Trade Information
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQTrdInfo",
    "userId": "mocZueK622W",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450",
    "TradeInformationList": [
      {
        "Exch": "B",
        "ExchType": "C",
        "ScripCode": 500410,
        "ExchOrderID": "1557728588259000015"
      },
      {
        "Exch": "B",
        "ExchType": "C",
        "ScripCode": 500410,
        "ExchOrderID": "1557728588259000019"
      },
      {
        "Exch": "B",
        "ExchType": "C",
        "ScripCode": 500410,
        "ExchOrderID": "1557728588259000020"
      }
    ]
  }
}

# %%
# Margin
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQMarginV3",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450"
  }
}

# %%
# Order Book

{
  "head": {
    "responseCode": "IIFLMarRQOrdBkV2",
    "status": "0",
    "statusDescription": "Success"
  },
  "body": {
    "Message": "",
    "OrderBookDetail": [
      {
        "AHProcess": "N",
        "AfterHours": "\u0000",
        "AtMarket": "Y",
        "BrokerOrderId": 15941,
        "BrokerOrderTime": "/Date(1557382909280+0530)/",
        "BuySell": "B",
        "DelvIntra": "D",
        "DisClosedQty": 0,
        "Exch": "N",
        "ExchOrderID": "0",
        "ExchOrderTime": "/Date(315513000000+0530)/",
        "ExchType": "Y",
        "MarketLot": 0,
        "OldorderQty": 0,
        "OrderRequesterCode": "Dummy123",
        "OrderStatus": "Rejected By IIFL",
        "OrderValidUpto": "09-12-2021 11:51:49",
        "OrderValidity": 0,
        "PendingQty": 1,
        "Qty": 1,
        "Rate": 39000,
        "Reason": "Order rejected by RMS as margin required is Rs84135.24, while available margin is Rs80927",
        "RequestType": "P",
        "SLTriggerRate": 0,
        "SLTriggered": "N",
        "SMOProfitRate": 0,
        "SMOSLLimitRate": 0,
        "SMOSLTriggerRate": 0,
        "SMOTrailingSL": 0,
        "ScripCode": 1014,
        "ScripName": "SILVER 05 Dec 2021",
        "TerminalId": 0,
        "TradedQty": 0,
        "WithSL": "N"
      }
    ],
    "Status": 0
  }
}

# %%
# Trade Book
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQTrdBkV1",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450"
  }
}

# %%
# Holding
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQHoldingV2",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450"
  }
}

# %%
# DP Holdings
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQBackoffDPHolding",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450"
  }
}

# %%
# Net Position
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQNetPositionV4",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450"
  }
}

# %%
# Net Wise Position
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQNPNWV2",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450"
  }
}

# %%
# Equity Transactions

{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQBackoffEquitytransaction",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450",
    "FromDate": "20211001",
    "ToDate": "20190401"
  }
}

# %%
# Future Transactions

{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQBackoffFutureTransaction",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450",
    "FromDate": "20211001",
    "ToDate": "20190401"
  }
}

# %%
# Mutual Fund Transactions
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQBackoffMutulFundTransaction",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450",
    "FromDate": "20211001",
    "ToDate": "20190401"
  }
}

# %%
# DP Transactions
{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQBackoffDPTransaction",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450",
    "FromDate": "20211001",
    "ToDate": "20190401"
  }
}

# %%
# Ledger

{
  "head": {
    "appName": "IIFLMarSITA RAM",
    "appVer": "1.0",
    "key": "xroOnxJ337SlMFT1q4gK8yMwvUwfBzTz",
    "osName": "Android",
    "requestCode": "IIFLMarRQBackoffLedger",
    "userId": "KgKgC0DSj3H",
    "password": "eAEJaXRkgPn"
  },
  "body": {
    "ClientCode": "18143450",
    "FromDate": "20211001",
    "ToDate": "20211115"
  }
}

# %%
# End of the code
